# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv("data.csv", encoding="gbk")

# %%
df.head(10)
# Out:
#    stu_id              time  course_index                   name      type  \
# 0       0     2017/6/1 9:02             0               中国建筑史（上）  艺术·设计 历史
# 1       0     2017/7/4 7:52             1                外国工艺美术史     艺术·设计
# 2       0     2017/7/4 7:55             2                  心理学概论     社科·法律
# 3       0    2017/7/20 5:35             3                  经济学原理     经管·会计
# 4       0   2017/11/14 5:36             4                   公司金融     经管·会计
# 5       0   2017/11/14 6:15             5        创业102：你能为客户做什么？  创业 经管·会计
# 6       0   2017/11/29 3:09             6  e时代的教与学――MOOC引发的混合式教学        教育
# 7       0    2018/3/21 7:25             7              党的十九大精神概论     社科·法律
# 8       1  2016/12/21 12:09             8     e时代的大佬师——慕课教师的修炼心法        教育
# 9       1     2017/1/5 8:05             9               大学物理近代物理        物理
#
#    type_id
# 0     20.0
# 1     20.0
# 2     13.0
# 3     10.0
# 4     10.0
# 5      1.0
# 6      9.0
# 7     13.0
# 8      9.0
# 9     18.0

# %%
# the number of each feature
df.nunique()
# Out:
# stu_id           82535
# time            295658
# course_index      1302
# name              1302
# type                79
# type_id             23
# dtype: int64

# %%
# the distribution of user's chosen courses
df_coursecount = df.groupby("stu_id").size().reset_index(name='coursenum')
plt.hist(df_coursecount["coursenum"], 30, range=[0, 40])
plt.ylabel('count')  
df_coursecount.describe()
# Out:
#              stu_id     coursenum
# count  82535.000000  82535.000000
# mean   41267.000000      5.554650
# std    23825.946571      5.657158
# min        0.000000      3.000000
# 25%    20633.500000      3.000000
# 50%    41267.000000      4.000000
# 75%    61900.500000      6.000000
# max    82534.000000    398.000000

# %%
# the distribution of user's chosen type
df.groupby("type_id").size().plot(kind='bar')
plt.ylabel('count') 

plt.show()

# %%
df.groupby("type_id").size().reset_index(name='chosen_times').sort_values('chosen_times', ascending = False)
# Out:
#     type_id  chosen_times
# 6       7.0        111542
# 18     19.0         68895
# 12     13.0         46372
# 2       3.0         38911
# 9      10.0         24394
# 19     20.0         20185
# 1       2.0         19840
# 15     16.0         17659
# 16     17.0         15163
# 17     18.0         14531
# 14     15.0         14186
# 8       9.0         10784
# 10     11.0         10380
# 20     21.0         10012
# 0       1.0          9793
# 22     23.0          9204
# 3       4.0          6609
# 13     14.0          3372
# 4       5.0          3243
# 5       6.0          1221
# 21     22.0          1139
# 7       8.0           641
# 11     12.0           368

# %%
df[df['type_id']==18]
# Out:
#         stu_id              time  course_index                 name type  \
# 9            1     2017/1/5 8:05             9             大学物理近代物理   物理
# 21           2    2017/8/21 7:54             9             大学物理近代物理   物理
# 45           7    2017/1/7 23:43            32              量子力学（上）   物理
# 52           8    2017/9/24 5:41            32              量子力学（上）   物理
# 223         38   2018/3/20 14:31            32              量子力学（上）   物理
# ...        ...               ...           ...                  ...  ...
# 458255   82517  2017/12/29 11:22            32              量子力学（上）   物理
# 458256   82517  2017/12/29 11:34           229        大学物理1 (力学、热学)   物理
# 458291   82522  2017/12/29 14:42           357  大学物理2 (电磁学、光学和量子物理)   物理
# 458385   82528    2018/1/21 9:48           206               光电仪器设计   物理
# 458412   82528   2018/2/21 11:20           235                   力学   物理
#
#         type_id
# 9          18.0
# 21         18.0
# 45         18.0
# 52         18.0
# 223        18.0
# ...         ...
# 458255     18.0
# 458256     18.0
# 458291     18.0
# 458385     18.0
# 458412     18.0
#
# [14531 rows x 6 columns]

# %%
# the distribution of user's chosen type
df_typecount = df.groupby("stu_id")['type_id'].nunique().reset_index(name='typenum')
df_typecount.groupby(["typenum"]).size().plot(kind='bar')
plt.ylabel('count')  
df_typecount.describe()
# Out:
#              stu_id       typenum
# count  82535.000000  82535.000000
# mean   41267.000000      2.889659
# std    23825.946571      1.872056
# min        0.000000      1.000000
# 25%    20633.500000      2.000000
# 50%    41267.000000      3.000000
# 75%    61900.500000      3.000000
# max    82534.000000     21.000000

# %%
# the most popular courses
top_course = df[["course_index","name","type","type_id"]]
top_course['choosen_times'] = top_course.groupby("course_index").size()
top_course = top_course.sort_values('choosen_times', ascending = False)
top_course.head(20)
# Out:
#      course_index              name      type  type_id  choosen_times
# 17             17           数据结构（上）       计算机      7.0        11058.0
# 14             14       C++语言程序设计基础       计算机      7.0         9050.0
# 10             10  计算机科学和Python编程导论       计算机      7.0         8292.0
# 214            26           网络技术与应用       计算机      7.0         8096.0
# 18             18              操作系统       计算机      7.0         6874.0
# 367           191         运营概论（微慕课）  工程 经管·会计      3.0         5949.0
# 15             15            生活英语听说        外语     16.0         5901.0
# 732           290          网络、群体与市场       计算机      7.0         5726.0
# 943           148     面向对象程序设计（C++）       计算机      7.0         5699.0
# 942            17           数据结构（上）       计算机      7.0         5684.0
# 941            24        分布式存储与资源管理       计算机      7.0         5671.0
# 872           327               太阳能     工程 物理      3.0         5669.0
# 948           336             艺术心理学     艺术·设计     20.0         5636.0
# 137            87              有机化学        化学      5.0         5092.0
# 793           304           汽车发动机原理        工程      3.0         4642.0
# 53             37            统计信号处理        工程      3.0         4592.0
# 21              9          大学物理近代物理        物理     18.0         4588.0
# 3               3             经济学原理     经管·会计     10.0         4232.0
# 29             26           网络技术与应用       计算机      7.0         4214.0
# 90             40             创新材料学     电子 工程      2.0         3974.0
